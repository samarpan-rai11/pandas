# %%
import numpy as np
import pandas as pd

# %%
company = pd.read_csv('fortune 500.csv')

# %%
company.head(2)
# Out:
#    Rank               Title                           Website  Employees  \
# 0     1             Walmart            http://www.walmart.com    2300000
# 1     2  Berkshire Hathaway  http://www.berkshirehathaway.com     367700
#
#        Sector                                  Industry       Hqlocation  \
# 0   Retailing                     General Merchandisers  Bentonville, AR
# 1  Financials  Insurance: Property and Casualty (Stock)        Omaha, NE
#
#                 Hqaddr       Hqcity Hqstate  ...  \
# 0  702 S.W. Eighth St.  Bentonville      AR  ...
# 1      3555 Farnam St.        Omaha      NE  ...
#
#                                        Ceo-title  \
# 0  President, Chief Executive Officer & Director
# 1             Chairman & Chief Executive Officer
#
#                                       Address Ticker                 Fullname  \
# 0  702 S.W. Eighth St., Bentonville, AR 72716    WMT    Wal-Mart Stores, Inc.
# ...

# %%
company.info()      #information about datatype and count
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         500 non-null    int64
#  1   Title        500 non-null    object
#  2   Website      500 non-null    object
#  3   Employees    500 non-null    int64
#  4   Sector       500 non-null    object
#  5   Industry     500 non-null    object
#  6   Hqlocation   500 non-null    object
#  7   Hqaddr       500 non-null    object
#  8   Hqcity       500 non-null    object
#  9   Hqstate      500 non-null    object
#  10  Hqzip        500 non-null    int64
#  11  Hqtel        500 non-null    object
#  12  Ceo          500 non-null    object
#  13  Ceo-title    500 non-null    object
#  14  Address      500 non-null    object
#  15  Ticker       500 non-null    object
#  16  Fullname     500 non-null    object
#  17  Revenues     500 non-null    int64
# ...

# %%
company.describe()
# Out:
#              Rank     Employees         Hqzip       Revenues  Revchange  \
# count  500.000000  5.000000e+02    500.000000     500.000000  500.00000
# mean   250.492000  5.635013e+04  46791.714000   24111.748000    3.75800
# std    144.477366  1.234520e+05  30160.384765   38337.353337   19.96748
# min      1.000000  8.300000e+01   1104.000000    5145.000000  -57.50000
# 25%    125.750000  1.190000e+04  19099.000000    7245.000000   -3.82500
# 50%    250.500000  2.500000e+04  46244.500000   11384.000000    1.90000
# 75%    375.250000  5.682525e+04  75045.000000   22605.250000    7.32500
# max    500.000000  2.300000e+06  98188.000000  485873.000000  197.30000
#
#             Profits        Assets  Totshequity
# count    500.000000  5.000000e+02     500.0000
# mean    1779.479800  8.038934e+04   13640.1470
# std     3937.558721  2.704257e+05   30523.1538
# min    -6177.000000  4.370000e+02  -12688.0000
# 25%      235.725000  8.436500e+03    1997.5000
# ...

# %% [markdown]
# # The groupby( ) function

# %% [markdown]
# groupby( ) function creates group of the given series like below of 'Sector'. It is for categorical data that repeats itself multiple time and this function helps to group them

# %%
sectors = company.groupby('Sector')

# %%
len(sectors)
# Out:
# 21

# %%
#size function gives total no. of each sector that we grouped

sectors.size().sort_values(ascending=False)
# Out:
# Sector
# Financials                       84
# Energy                           57
# Retailing                        47
# Technology                       43
# Health Care                      38
# Wholesalers                      29
# Food, Beverages & Tobacco        24
# Business Services                20
# Materials                        19
# Industrials                      19
# Transportation                   17
# Chemicals                        14
# Engineering & Construction       13
# Aerospace & Defense              12
# Household Products               12
# Media                            11
# Telecommunications               10
# Hotels, Restaurants & Leisure    10
# Motor Vehicles & Parts            9
# Food & Drug Stores                7
# Apparel                           5
# dtype: int64

# %%
sectors.first()   #this function will give first company of each sector
# Out:
#                                Rank                     Title  \
# Sector
# Aerospace & Defense              24                    Boeing
# Apparel                          88                      Nike
# Business Services               146             ManpowerGroup
# Chemicals                        62              Dow Chemical
# Energy                            4               Exxon Mobil
# Engineering & Construction      149                     Fluor
# Financials                        2        Berkshire Hathaway
# Food & Drug Stores               17  Walgreens Boots Alliance
# Food, Beverages & Tobacco        44                   PepsiCo
# Health Care                       6        UnitedHealth Group
# Hotels, Restaurants & Leisure   112                McDonald’s
# Household Products               36          Procter & Gamble
# Industrials                      13          General Electric
# Materials                       133       International Paper
# ...

# %%
sectors.last()     #this function will give last company of each sector
# Out:
#                                Rank                               Title  \
# Sector
# Aerospace & Defense             492                    Rockwell Collins
# Apparel                         432                         Hanesbrands
# Business Services               500                      ABM Industries
# Chemicals                       484                            Celanese
# Energy                          499                       Vistra Energy
# Engineering & Construction      497                       Toll Brothers
# Financials                      483  Western & Southern Financial Group
# Food & Drug Stores              176                  Whole Foods Market
# Food, Beverages & Tobacco       486                            Seaboard
# Health Care                     454                  Genesis Healthcare
# Hotels, Restaurants & Leisure   461                   Wyndham Worldwide
# Household Products              474                              Mattel
# ...

# %%
#this will give us dictionaries of sectors where key is sector and value is index of the companies

sectors.groups
# Out:
# {'Aerospace & Defense': [23, 49, 55, 89, 113, 115, 199, 227, 272, 379, 392, 491], 'Apparel': [87, 229, 334, 370, 431], 'Business Services': [145, 178, 186, 191, 200, 239, 241, 263, 266, 298, 300, 344, 377, 451, 458, 470, 477, 489, 492, 499], 'Chemicals': [61, 112, 182, 203, 210, 235, 274, 288, 293, 308, 376, 466, 481, 483], 'Energy': [3, 18, 33, 36, 50, 78, 88, 102, 114, 116, 120, 121, 140, 144, 156, 166, 169, 171, 172, 174, 193, 195, 214, 228, 230, 233, 234, 236, 237, 255, 262, 271, 273, 277, 279, 284, 307, 311, 327, 342, 343, 348, 355, 357, 361, 364, 366, 367, 374, 399, 401, 418, 430, 456, 479, 487, 498], 'Engineering & Construction': [148, 160, 231, 258, 259, 323, 352, 354, 359, 414, 445, 493, 496], 'Financials': [1, 19, 20, 24, 25, 29, 32, 38, 41, 47, 54, 64, 67, 74, 75, 76, 77, 79, 83, 85, 96, 98, 99, 101, 119, 124, 125, 152, 165, 167, 176, 184, 188, 206, 209, 212, 213, 217, 221, 226, 238, 244, 245, 254, 257, 261, 265, 270, 276, 285, 292, 301, 302, 314, 315, 328, 341, 353, 356, 
# ...

# %%
#this function will give every company of the sector passed in function

sectors.get_group('Apparel')
# Out:
#      Rank         Title                     Website  Employees   Sector  \
# 87     88          Nike         http://www.nike.com      70700  Apparel
# 229   230            VF          http://www.vfc.com      69000  Apparel
# 334   335           PVH          http://www.pvh.com      26650  Apparel
# 370   371  Ralph Lauren  http://www.ralphlauren.com      20500  Apparel
# 431   432   Hanesbrands        http://www.hanes.com      67800  Apparel
#
#     Industry         Hqlocation                      Hqaddr         Hqcity  \
# 87   Apparel      Beaverton, OR              1 Bowerman Dr.      Beaverton
# 229  Apparel     Greensboro, NC  105 Corporate Center Blvd.     Greensboro
# 334  Apparel       New York, NY            200 Madison Ave.       New York
# 370  Apparel       New York, NY            650 Madison Ave.       New York
# 431  Apparel  Winston-Salem, NC      1000 E. Hanes Mill Rd.  Winston-Salem
#
#     Hqstate  ...                                      Ceo-title  \
# ...

# %%
#sum of profits of every sectors

sectors['Profits'].sum().sort_values(ascending=False)
# Out:
# Sector
# Financials                       228461.2
# Technology                       177901.4
# Health Care                      105383.9
# Food, Beverages & Tobacco         56308.4
# Retailing                         46613.9
# Telecommunications                41272.8
# Industrials                       32826.1
# Transportation                    28395.0
# Aerospace & Defense               25119.7
# Business Services                 23107.1
# Media                             20034.7
# Household Products                19803.7
# Motor Vehicles & Parts            17275.8
# Chemicals                         15918.3
# Hotels, Restaurants & Leisure     14510.6
# Wholesalers                       11347.1
# Food & Drug Stores                 8522.0
# Apparel                            6318.5
# Materials                          5176.9
# Engineering & Construction         5072.2
# Energy                              370.6
# Name: Profits, dtype: float64

# %%
#mean of profits of every sectors

sectors['Profits'].mean().sort_values(ascending=False)
# Out:
# Sector
# Technology                       4137.241860
# Telecommunications               4127.280000
# Health Care                      2773.260526
# Financials                       2719.776190
# Food, Beverages & Tobacco        2346.183333
# Aerospace & Defense              2093.308333
# Motor Vehicles & Parts           1919.533333
# Media                            1821.336364
# Industrials                      1727.689474
# Transportation                   1670.294118
# Household Products               1650.308333
# Hotels, Restaurants & Leisure    1451.060000
# Apparel                          1263.700000
# Food & Drug Stores               1217.428571
# Business Services                1155.355000
# Chemicals                        1137.021429
# Retailing                         991.785106
# Wholesalers                       391.279310
# Engineering & Construction        390.169231
# Materials                         272.468421
# Energy                              6.501754
# ...

# %%
sectors[['Revenues','Profits']].sum()
# Out:
#                                Revenues   Profits
# Sector
# Aerospace & Defense              338302   25119.7
# Apparel                           66254    6318.5
# Business Services                194685   23107.1
# Chemicals                        188667   15918.3
# Energy                          1176417     370.6
# Engineering & Construction       124682    5072.2
# Financials                      2067607  228461.2
# Food & Drug Stores               389686    8522.0
# Food, Beverages & Tobacco        472806   56308.4
# Health Care                     1318389  105383.9
# Hotels, Restaurants & Leisure    121189   14510.6
# Household Products               180846   19803.7
# Industrials                      418359   32826.1
# Materials                        169755    5176.9
# Media                            180767   20034.7
# Motor Vehicles & Parts           392466   17275.8
# Retailing                       1383281   46613.9
# Technology                      1257589  177901.4
# ...
